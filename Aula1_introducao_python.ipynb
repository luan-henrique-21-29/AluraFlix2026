# %% [markdown]
# <a href="https://colab.research.google.com/github/luan-henrique-21-29/AluraFlix2026/blob/main/Aula1_introducao_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World! Meu primeiro Código no Colab.")
from google.colab import userdata

# Busca o segredo guardado no painel da chave sem expor o texto na tela
api_key = userdata.get('GOOGLE_API_KEY')
print("Chave carregada com segurança!")
